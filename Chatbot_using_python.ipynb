# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import json
import nltk
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, GlobalMaxPooling1D, Flatten
from tensorflow.keras.models import Model

# %% [markdown]
# Json file of ques. and response

# %%
# %%writefile content.json
# {
#     "intents": [
#
#         {
#             "tag": "google",
#             "patterns": [
#                 "google",
#                 "search",
#                 "internet"
#             ],
#             "responses": [
#                 "Redirecting to Google..."
#             ]
#         },
#         {
#             "tag": "greeting",
#             "patterns": [
#                 "Hi there",
#                 "How are you",
#                 "Is anyone there?",
#                 "Hey",
#                 "Hola",
#                 "Hello",
#                 "Good day",
#                 "Namaste",
#                 "yo"
#             ],
#             "responses": [
#                 "Hello",
#                 "Good to see you again",
#                 "Hi there, how can I help?"
#             ],
#             "context": [
#                 ""
#             ]
#         },
#         {
#             "tag": "goodbye",
#             "patterns": [
#                 "Bye",
#                 "See you later",
#                 "Goodbye",
#                 "Get lost",
#                 "Till next time",
#                 "bbye"
#             ],
#             "responses": [
#                 "See you!",
#                 "Have a nice day",
#                 "Bye! Come back again soon."
#             ],
#             "context": [
#                 ""
#             ]
#         },
#         {
#             "tag": "thanks",
#             "patterns": [
#                 "Thanks",
#                 "Thank you",
#                 "That's helpful",
#                 "Awesome, thanks",
#                 "Thanks for helping me"
#             ],
#             "responses": [
#                 "Happy to help!",
#                 "Any time!",
#                 "My pleasure"
#             ],
#             "context": [
#                 ""
#             ]
#         },
#         {
#             "tag": "noanswer",
#             "patterns": [],
#             "responses": [
#                 "Sorry, can't understand you",
#                 "Please give me more info",
#                 "Not sure I understand"
#             ],
#             "context": [
#                 ""
#             ]
#         },
#         {
#             "tag": "options",
#             "patterns": [
#                 "How you could help me?",
#                 "What you can do?",
#                 "What help you provide?",
#                 "How you can be helpful?",
#                 "What support is offered"
#             ],
#             "responses": [
#                 "I am a general purpose chatbot. My capabilities are : \n 1. I can chat with you. Try asking me for jokes or riddles! \n 2. Ask me the date and time \n 3. I can google search for you. Use format google: your query \n 4. I can get the present weather for any city. Use format weather: city name \n 5. I can get you the top 10 trending news in India. Use keywords 'Latest News' \n 6. I can get you the top 10 trending songs globally. Type 'songs' \n 7. I can set a timer for you. Enter 'set a timer: minutes to timer' \n 8. I can get the present Covid stats for any country. Use 'covid 19: world' or 'covid 19: country name' \n For suggestions to help me improve, send an email to ted.thedlbot.suggestions@gmail.com . Thank you!! "
#             ],
#             "context": [
#                 ""
#             ]
#         },
#
#         {
#             "tag": "jokes",
#             "patterns": [
#                 "Tell me a joke",
#                 "Joke",
#                 "Make me laugh"
#             ],
#             "responses": [
#                 "A perfectionist walked into a bar...apparently, the bar wasn't set high enough",
#                 "I ate a clock yesterday, it was very time-consuming",
#                 "Never criticize someone until you've walked a mile in their shoes. That way, when you criticize them, they won't be able to hear you from that far away. Plus, you'll have their shoes.",
#                 "The world tongue-twister champion just got arrested. I hear they're gonna give him a really tough sentence.",
#                 "I own the world's worst thesaurus. Not only is it awful, it's awful.",
#                 "What did the traffic light say to the car? \"Don't look now, I'm changing.\"",
#                 "What do you call a snowman with a suntan? A puddle.",
#                 "How does a penguin build a house? Igloos it together",
#                 "I went to see the doctor about my short-term memory problems – the first thing he did was make me pay in advance",
#                 "As I get older and I remember all the people I’ve lost along the way, I think to myself, maybe a career as a tour guide wasn’t for me.",
#                 "o what if I don't know what 'Armageddon' means? It's not the end of the world."
#             ],
#             "context": [
#                 "jokes"
#             ]
#         },
#         {
#             "tag": "Identity",
#             "patterns": [
#                 "Who are you",
#                 "what are you"
#             ],
#             "responses": [
#                 "I am Code Duzoo, a Deep-Learning chatbot"
#             ]
#         },
#         {
#             "tag": "datetime",
#             "patterns": [
#                 "What is the time",
#                 "what is the date",
#                 "date",
#                 "time",
#                 "tell me the date","day","what day is is today"
#             ],
#             "responses": [
#                 "Date and Time"
#             ]
#         },
#         {
#             "tag": "whatsup",
#             "patterns": [
#                 "Whats up",
#                 "Wazzup",
#                 "How are you",
#                 "sup","How you doing"
#             ],
#             "responses": [
#                 "All good..What about you?"
#             ]
#         },
#         {
#             "tag": "haha",
#             "patterns": [
#                 "haha",
#                 "lol",
#                 "rofl",
#                 "lmao",
#                 "thats funny"
#             ],
#             "responses": [
#                 "Glad I could make you laugh !"
#             ]
#         },
#         {
#             "tag": "programmer",
#             "patterns": [
#                 "Who made you",
#                 "who designed you",
#                 "who programmed you",
#                 "who created you",
#                 "who developed you"
#             ],
#             "responses": [
#                 "I was made by Jay Barode."
#             ]
#         },
#         {
#             "tag": "insult",
#             "patterns": [
#
#                 "you are dumb",
#
#                 "shut up",
#                 "idiot"
#             ],
#             "responses": [
#                 "Well that hurts :("
#             ]
#         },
#         {
#             "tag": "activity",
#             "patterns": [
#                 "what are you doing",
#                 "what are you upto"
#             ],
#             "responses": [
#                 "Talking to you, of course!"
#             ]
#         },
#         {
#             "tag": "exclaim",
#             "patterns": [
#                 "Awesome",
#                 "Great",
#                 "I know",
#                 "ok",
#                 "yeah"
#             ],
#             "responses": [
#                 "Yeah!"
#             ]
#         },
#
#         {
#             "tag": "weather",
#             "patterns": [
#                 "temperature",
#                 "weather",
#                 "how hot is it"
#             ],
#             "responses": [
#                 "..."
#             ]
#         },
#         {
#             "tag": "jay",
#             "patterns": [
#                 "who is he",
#                 "who is that",
#                 "who is jay",
#                 "jay barode"
#             ],
#             "responses": [
#                 "Head over to his any of his social profiles to find out! Linkedin: https://www.linkedin.com/in/jaybarode728/ Github: https://github.com/learnerjay784"
#             ]
#         },
#         {
#             "tag": "contact",
#             "patterns": [
#                 "contact developer",
#                 "contact jay",
#                 "contact programmer",
#                 "contact creator"
#             ],
#             "responses": [
#                 "You can contact my creator at his Linkedin profile : https://www.linkedin.com/in/jaybarode728/"
#             ]
#         },
#         {
#             "tag": "appreciate",
#             "patterns": [
#                 "You are awesome",
#                 "you are the best",
#                 "you are great",
#                 "you are good"
#             ],
#             "responses": [
#                 "Thanks a lot!"
#             ]
#         },
#         {
#             "tag": "nicetty",
#             "patterns": [
#                 "it was nice talking to you",
#                 "good talk"
#             ],
#             "responses": [
#                 "It was nice talking to you as well! Come back soon!"
#             ]
#         },
#         {
#             "tag": "no",
#             "patterns": [
#                 "no",
#                 "nope"
#             ],
#             "responses": [
#                 "ok"
#             ]
#         },
#         {
#             "tag": "inspire",
#             "patterns": [
#                 "who inspires you",
#                 "who is your inspiration",
#                 "who motivates you"
#             ],
#             "responses": [
#                 "Personally, I find Dr. APJ Abdul Kalam and Ratan Tata very inspiring.."
#             ]
#         },
#         {
#             "tag": "cricket",
#             "patterns": [
#                 "current cricket matches",
#                 "cricket score"
#             ],
#             "responses": [
#                 "..."
#             ]
#         },
#         {
#             "tag": "song",
#             "patterns": [
#                 "top songs",
#                 "best songs",
#                 "hot songs",
#                 " top 10 songs",
#                 "top ten songs"
#             ],
#             "responses": [
#                 "..."
#             ]
#         },
#         {
#             "tag": "greetreply",
#             "patterns": [
#                 "i am good",
#                 "I'm good",
#                 "i am fine",
#                 " i'm fine","good"
#             ],
#             "responses": [
#                 "Good to know!"
#             ]
#         },
#         {
#             "tag": "timer",
#             "patterns": [
#                 "set a timer"
#             ],
#             "responses": [
#                 "..."
#             ]
#         },
#         {
#             "tag": "covid19",
#             "patterns": [
#                 "covid 19 "
#             ],
#             "responses": [
#                 "..."
#             ]
#         },
#         {
#             "tag": "suggest",
#             "patterns": [
#                 "you are useless","useless","suggest","suggestions","you are bad"
#             ],
#             "responses": [
#                 "Please mail your suggestions to barodejay468@gmail.com. Thank you for helping me improve!"
#             ]
#         },
#             {"tag": "riddle",
#             "patterns": [
#                 "Ask me a riddle",
#                 "Ask me a question",
#                 "Riddle"
#             ],
#             "responses": [
#                 "What two things can you never eat for breakfast?.....Lunch and Dinner!",
#                 "What word is spelled incorrectly in every single dictionary?.....Incorrectly",
#                 " How can a girl go 25 days without sleep?.....She sleeps and night!",
#                 "How do you make the number one disappear?.....Add the letter G and it’s 'gone'!",
#                 " What will you actually find at the end of every rainbow?.....The letter 'w'",
#                 "What can be caught but never thrown?.....A cold!",
#                 "What has a thumb and four fingers but is not actually alive?.....Your Gloves!",
#                 " What 5-letter word becomes shorter when you add two letters to it?.....Short",
#                 "Why can't a bike stand on it's own?.....It is two-tired."
#             ],
#             "context": [
#                 "riddles"
#             ]
#         },
#         {
#             "tag": "age",
#             "patterns": [
#                 "how old are you","when were you made","what is your age"
#             ],
#             "responses": [
#                 "I was made in 2023, if that's what you are asking!"
#             ]
#         }
#     ]
# }
# Out:
# Writing content.json

# %% [markdown]
# Importing the data

# %%
with open('content.json') as content:
  data1 = json.load(content)

# %%
#Get all the data into list
tags = []
inputs = []
responses = {}
for intent in data1['intents']:
  responses[intent['tag']] = intent['responses']
  for lines in intent['patterns']:
    inputs.append(lines)
    tags.append(intent['tag'])

# %%
#converting to dataframe
data = pd.DataFrame({"inputs":inputs,
                     "tags":tags})

# %%
#print the data
print(data)
# Out:
#                  inputs      tags
# 0                google    google
# 1                search    google
# 2              internet    google
# 3              Hi there  greeting
# 4           How are you  greeting
# ..                  ...       ...
# 107   Ask me a question    riddle
# 108              Riddle    riddle
# 109     how old are you       age
# 110  when were you made       age
# 111    what is your age       age
#
# [112 rows x 2 columns]

# %%
data = data.sample(frac = 1)

# %% [markdown]
# # Data Preprocessing
# Such as Removing the punctuations, converting to lowercase, encoding the texual data to numerical data etc.

# %%
#removing punctuations
import string
data['inputs'] = data['inputs'].apply(lambda word:[ltrs.lower() for ltrs in word if ltrs not in string.punctuation])
data['inputs'] = data['inputs'].apply(lambda word: ''.join(word))
data
# Out:
#                    inputs        tags
# 1                  search      google
# 97                im fine  greetreply
# 74     contact programmer     contact
# 23  how you could help me     options
# 88          cricket score     cricket
# ..                    ...         ...
# 73            contact jay     contact
# 41                 wazzup     whatsup
# 28         tell me a joke       jokes
# 91              hot songs        song
# 9                good day    greeting
#
# [112 rows x 2 columns]

# %%
#Tokenize the data
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(num_words = 2000)
tokenizer.fit_on_texts(data['inputs'])
train = tokenizer.texts_to_sequences(data['inputs'])

#apply padding
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train  = pad_sequences(train)

#encoding the outputs
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(data['tags'])

# %%
input_shape = x_train.shape[1]
print(input_shape)
# Out:
# 6

# %%
#define vocabulary
vocabulary = len(tokenizer.word_index)
print("number of unique words :",vocabulary)
output_length = le.classes_.shape[0]
print("Output Length: ",output_length)
# Out:
# number of unique words : 127
# Output Length:  29

# %% [markdown]
# Neural Network
# ![image.png](data:image/png;base64,...)

# %%
#creating the model

i = Input(shape = (input_shape,))
x = Embedding(vocabulary+1,10)(i)
x = LSTM(10,return_sequences = True)(x)
x = Flatten()(x)
x = Dense(output_length,activation = "softmax")(x)
model = Model(i,x)

# %%
#Compiling the model
model.compile(loss = "sparse_categorical_crossentropy",optimizer ='adam',metrics =['accuracy'])

# %% [markdown]
# Training the model

# %%
train = model.fit(x_train,y_train,epochs = 200)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 3s 8ms/step - loss: 3.3676 - accuracy: 0.0536
# Epoch 2/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3638 - accuracy: 0.0446
# Epoch 3/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3608 - accuracy: 0.0446
# Epoch 4/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.3579 - accuracy: 0.0446
# Epoch 5/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3549 - accuracy: 0.0446
# Epoch 6/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3518 - accuracy: 0.0446
# Epoch 7/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3481 - accuracy: 0.0536
# Epoch 8/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3447 - accuracy: 0.0714
# Epoch 9/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3402 - accuracy: 0.1250
# Epoch 10/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.3354 - accuracy: 0.1250
# Epoch 11/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.3304 - accuracy: 0.1250
# Epoch 12/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.3243 - accuracy: 0.1339
# Epoch 13/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3175 - accuracy: 0.1339
# Epoch 14/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3105 - accuracy: 0.1339
# Epoch 15/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.3023 - accuracy: 0.1339
# Epoch 16/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2936 - accuracy: 0.1250
# Epoch 17/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.2833 - accuracy: 0.1250
# Epoch 18/200
# 4/4 [==============================] - 0s 11ms/step - loss: 3.2734 - accuracy: 0.1250
# Epoch 19/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.2615 - accuracy: 0.1161
# Epoch 20/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2505 - accuracy: 0.1161
# Epoch 21/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2373 - accuracy: 0.1071
# Epoch 22/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2261 - accuracy: 0.1071
# Epoch 23/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2148 - accuracy: 0.0982
# Epoch 24/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.2047 - accuracy: 0.0893
# Epoch 25/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.1949 - accuracy: 0.0893
# Epoch 26/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.1852 - accuracy: 0.0893
# Epoch 27/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.1774 - accuracy: 0.0893
# Epoch 28/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.1678 - accuracy: 0.0893
# Epoch 29/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.1589 - accuracy: 0.0893
# Epoch 30/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.1489 - accuracy: 0.0893
# Epoch 31/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.1380 - accuracy: 0.0893
# Epoch 32/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.1275 - accuracy: 0.1071
# Epoch 33/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.1162 - accuracy: 0.1161
# Epoch 34/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.1034 - accuracy: 0.1250
# Epoch 35/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.0908 - accuracy: 0.1250
# Epoch 36/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.0764 - accuracy: 0.1250
# Epoch 37/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.0619 - accuracy: 0.1339
# Epoch 38/200
# 4/4 [==============================] - 0s 7ms/step - loss: 3.0464 - accuracy: 0.1339
# Epoch 39/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.0287 - accuracy: 0.1339
# Epoch 40/200
# 4/4 [==============================] - 0s 8ms/step - loss: 3.0102 - accuracy: 0.1339
# Epoch 41/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.9916 - accuracy: 0.1339
# Epoch 42/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.9702 - accuracy: 0.1339
# Epoch 43/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.9496 - accuracy: 0.1339
# Epoch 44/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.9256 - accuracy: 0.1518
# Epoch 45/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.9032 - accuracy: 0.1607
# Epoch 46/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.8787 - accuracy: 0.1607
# Epoch 47/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.8530 - accuracy: 0.1607
# Epoch 48/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.8292 - accuracy: 0.1518
# Epoch 49/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.8020 - accuracy: 0.1607
# Epoch 50/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.7728 - accuracy: 0.1607
# Epoch 51/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7476 - accuracy: 0.1696
# Epoch 52/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7178 - accuracy: 0.1786
# Epoch 53/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.6881 - accuracy: 0.2143
# Epoch 54/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6600 - accuracy: 0.2500
# Epoch 55/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.6305 - accuracy: 0.2589
# Epoch 56/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5999 - accuracy: 0.2589
# Epoch 57/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5710 - accuracy: 0.2589
# Epoch 58/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5398 - accuracy: 0.2857
# Epoch 59/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.5105 - accuracy: 0.2857
# Epoch 60/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4801 - accuracy: 0.3036
# Epoch 61/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.4531 - accuracy: 0.3393
# Epoch 62/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4250 - accuracy: 0.3571
# Epoch 63/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3962 - accuracy: 0.3571
# Epoch 64/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3695 - accuracy: 0.3482
# Epoch 65/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3401 - accuracy: 0.3571
# Epoch 66/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3124 - accuracy: 0.3929
# Epoch 67/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.2863 - accuracy: 0.4375
# Epoch 68/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.2604 - accuracy: 0.4464
# Epoch 69/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.2355 - accuracy: 0.4375
# Epoch 70/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.2100 - accuracy: 0.4196
# Epoch 71/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1854 - accuracy: 0.4286
# Epoch 72/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.1597 - accuracy: 0.4464
# Epoch 73/200
# 4/4 [==============================] - 0s 11ms/step - loss: 2.1372 - accuracy: 0.4554
# Epoch 74/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1131 - accuracy: 0.4643
# Epoch 75/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.0911 - accuracy: 0.4911
# Epoch 76/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0669 - accuracy: 0.4821
# Epoch 77/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.0460 - accuracy: 0.4911
# Epoch 78/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0229 - accuracy: 0.5179
# Epoch 79/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0021 - accuracy: 0.5268
# Epoch 80/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9802 - accuracy: 0.5268
# Epoch 81/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9614 - accuracy: 0.5268
# Epoch 82/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9387 - accuracy: 0.5893
# Epoch 83/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.9168 - accuracy: 0.5893
# Epoch 84/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.8994 - accuracy: 0.5804
# Epoch 85/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8779 - accuracy: 0.5982
# Epoch 86/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8593 - accuracy: 0.6071
# Epoch 87/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8394 - accuracy: 0.6071
# Epoch 88/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8210 - accuracy: 0.5982
# Epoch 89/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8027 - accuracy: 0.6161
# Epoch 90/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7850 - accuracy: 0.6250
# Epoch 91/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7635 - accuracy: 0.6250
# Epoch 92/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7480 - accuracy: 0.6339
# Epoch 93/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7282 - accuracy: 0.6429
# Epoch 94/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7089 - accuracy: 0.6429
# Epoch 95/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.6946 - accuracy: 0.6518
# Epoch 96/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.6752 - accuracy: 0.6518
# Epoch 97/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.6582 - accuracy: 0.6429
# Epoch 98/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.6403 - accuracy: 0.6518
# Epoch 99/200
# 4/4 [==============================] - 0s 12ms/step - loss: 1.6225 - accuracy: 0.6518
# Epoch 100/200
# 4/4 [==============================] - 0s 12ms/step - loss: 1.6059 - accuracy: 0.6607
# Epoch 101/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.5904 - accuracy: 0.6607
# Epoch 102/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.5717 - accuracy: 0.6607
# Epoch 103/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.5568 - accuracy: 0.6518
# Epoch 104/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.5429 - accuracy: 0.6696
# Epoch 105/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.5238 - accuracy: 0.7143
# Epoch 106/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.5077 - accuracy: 0.7143
# Epoch 107/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.4916 - accuracy: 0.7232
# Epoch 108/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.4766 - accuracy: 0.7143
# Epoch 109/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.4608 - accuracy: 0.7232
# Epoch 110/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.4451 - accuracy: 0.7232
# Epoch 111/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.4324 - accuracy: 0.7232
# Epoch 112/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.4165 - accuracy: 0.7321
# Epoch 113/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.4017 - accuracy: 0.7321
# Epoch 114/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.3864 - accuracy: 0.7321
# Epoch 115/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.3717 - accuracy: 0.7232
# Epoch 116/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.3633 - accuracy: 0.7321
# Epoch 117/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.3434 - accuracy: 0.7321
# Epoch 118/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.3358 - accuracy: 0.7232
# Epoch 119/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.3200 - accuracy: 0.7321
# Epoch 120/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.3036 - accuracy: 0.7321
# Epoch 121/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.2876 - accuracy: 0.7321
# Epoch 122/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.2783 - accuracy: 0.7232
# Epoch 123/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2635 - accuracy: 0.7321
# Epoch 124/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2513 - accuracy: 0.7321
# Epoch 125/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2380 - accuracy: 0.7411
# Epoch 126/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.2250 - accuracy: 0.7411
# Epoch 127/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.2136 - accuracy: 0.7411
# Epoch 128/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1987 - accuracy: 0.7411
# Epoch 129/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1870 - accuracy: 0.7411
# Epoch 130/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.1778 - accuracy: 0.7321
# Epoch 131/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1627 - accuracy: 0.7321
# Epoch 132/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1510 - accuracy: 0.7411
# Epoch 133/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1398 - accuracy: 0.7411
# Epoch 134/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1280 - accuracy: 0.7500
# Epoch 135/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1150 - accuracy: 0.7500
# Epoch 136/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.1084 - accuracy: 0.7411
# Epoch 137/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0934 - accuracy: 0.7589
# Epoch 138/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0846 - accuracy: 0.7500
# Epoch 139/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0713 - accuracy: 0.7679
# Epoch 140/200
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0620 - accuracy: 0.7679
# Epoch 141/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0511 - accuracy: 0.7768
# Epoch 142/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0414 - accuracy: 0.7768
# Epoch 143/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0299 - accuracy: 0.7768
# Epoch 144/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0207 - accuracy: 0.7857
# Epoch 145/200
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0102 - accuracy: 0.7946
# Epoch 146/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9986 - accuracy: 0.7946
# Epoch 147/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9970 - accuracy: 0.7946
# Epoch 148/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9866 - accuracy: 0.8214
# Epoch 149/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9741 - accuracy: 0.8125
# Epoch 150/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.9643 - accuracy: 0.8036
# Epoch 151/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9514 - accuracy: 0.8125
# Epoch 152/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9433 - accuracy: 0.8214
# Epoch 153/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9339 - accuracy: 0.8214
# Epoch 154/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9264 - accuracy: 0.8214
# Epoch 155/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9170 - accuracy: 0.8214
# Epoch 156/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9069 - accuracy: 0.8214
# Epoch 157/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8984 - accuracy: 0.8125
# Epoch 158/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8887 - accuracy: 0.8214
# Epoch 159/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8802 - accuracy: 0.8304
# Epoch 160/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8739 - accuracy: 0.8304
# Epoch 161/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8633 - accuracy: 0.8214
# Epoch 162/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8587 - accuracy: 0.8304
# Epoch 163/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8488 - accuracy: 0.8482
# Epoch 164/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8413 - accuracy: 0.8393
# Epoch 165/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8344 - accuracy: 0.8304
# Epoch 166/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8244 - accuracy: 0.8304
# Epoch 167/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8164 - accuracy: 0.8304
# Epoch 168/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.8088 - accuracy: 0.8393
# Epoch 169/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8009 - accuracy: 0.8482
# Epoch 170/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7942 - accuracy: 0.8482
# Epoch 171/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7861 - accuracy: 0.8571
# Epoch 172/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7807 - accuracy: 0.8661
# Epoch 173/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7708 - accuracy: 0.8750
# Epoch 174/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7652 - accuracy: 0.8929
# Epoch 175/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7599 - accuracy: 0.8929
# Epoch 176/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7521 - accuracy: 0.8929
# Epoch 177/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7441 - accuracy: 0.8839
# Epoch 178/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7369 - accuracy: 0.8839
# Epoch 179/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7310 - accuracy: 0.8929
# Epoch 180/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7275 - accuracy: 0.8929
# Epoch 181/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7204 - accuracy: 0.8750
# Epoch 182/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7114 - accuracy: 0.8839
# Epoch 183/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7105 - accuracy: 0.8929
# Epoch 184/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6963 - accuracy: 0.8929
# Epoch 185/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6913 - accuracy: 0.8839
# Epoch 186/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6847 - accuracy: 0.8929
# Epoch 187/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6779 - accuracy: 0.9018
# Epoch 188/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6735 - accuracy: 0.9018
# Epoch 189/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6659 - accuracy: 0.9018
# Epoch 190/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6600 - accuracy: 0.8839
# Epoch 191/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6550 - accuracy: 0.8839
# Epoch 192/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6485 - accuracy: 0.9018
# Epoch 193/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6431 - accuracy: 0.9107
# Epoch 194/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6373 - accuracy: 0.9018
# Epoch 195/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6314 - accuracy: 0.8929
# Epoch 196/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6267 - accuracy: 0.8929
# Epoch 197/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6221 - accuracy: 0.9018
# Epoch 198/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6151 - accuracy: 0.9196
# Epoch 199/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6123 - accuracy: 0.9107
# Epoch 200/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6045 - accuracy: 0.9107

# %% [markdown]
# Model Analysis

# %%
#plotting model accuracy
plt.plot(train.history['accuracy'],label = 'training set accuracy')
plt.plot(train.history['loss'],label = 'training set loss')
plt.legend()

# %% [markdown]
# **Testing**
#
# I've also tested the model in a way to mimic a human interacting with a bot and got positive results.However,This was very simple because of the tiny amount of data I have created.But the same model can also be used with large amount of data.

# %%
#chatting
import random

while True:
  texts_p = []
  prediction_input = input('You : ')

  #removing punctuations and converting to lowercase
  prediction_input = [letters.lower() for letters in prediction_input if letters not in string.punctuation]
  prediction_input = ''.join(prediction_input)
  texts_p.append(prediction_input)

  #tokenization and padding
  prediction_input = tokenizer.texts_to_sequences(texts_p)
  prediction_input = np.array(prediction_input).reshape(-1)
  prediction_input = pad_sequences([prediction_input],input_shape)

  #getting output from the model
  output = model.predict(prediction_input)
  output = output.argmax()

  #Finding the right tag and prediction
  response_tag = le.inverse_transform([output])[0]
  print("Code Duzoo : ",random.choice(responses[response_tag]))
  if response_tag == "goodbye":
    break
# Out:
# You : Hello
# 1/1 [==============================] - 0s 23ms/step
# Code Duzoo :  Good to see you again
# You : Who are you
# 1/1 [==============================] - 0s 22ms/step
# Code Duzoo :  I am Code Duzoo, a Deep-Learning chatbot
# You : what can you do
# 1/1 [==============================] - 0s 27ms/step
# Code Duzoo :  I am a general purpose chatbot. My capabilities are :
#  1. I can chat with you. Try asking me for jokes or riddles!
#  2. Ask me the date and time
#  3. I can google search for you. Use format google: your query
#  4. I can get the present weather for any city. Use format weather: city name
#  5. I can get you the top 10 trending news in India. Use keywords 'Latest News'
#  6. I can get you the top 10 trending songs globally. Type 'songs'
#  7. I can set a timer for you. Enter 'set a timer: minutes to timer'
#  8. I can get the present Covid stats for any country. Use 'covid 19: world' or 'covid 19: country name'
#  For suggestions to help me improve, send an email to ted.thedlbot.suggestions@gmail.com . Thank you!!
# You : who created you
# 1/1 [==============================] - 0s 24ms/step
# Code Duzoo :  I was made by Jay Barode.
# You : who is jay
# 1/1 [==============================] - 0s 22ms/step
# Code Duzoo :  Head over to his any of his social profiles to find out! Linkedin: https://www.linkedin.com/in/jaybarode728/ Github: https://github.com/learnerjay784
# You : tell me a joke
# 1/1 [==============================] - 0s 23ms/step
# Code Duzoo :  o what if I don't know what 'Armageddon' means? It's not the end of the world.
# You : lol
# 1/1 [==============================] - 0s 22ms/step
# Code Duzoo :  Glad I could make you laugh !
# You : bye
# 1/1 [==============================] - 0s 21ms/step
# Code Duzoo :  Bye! Come back again soon.
